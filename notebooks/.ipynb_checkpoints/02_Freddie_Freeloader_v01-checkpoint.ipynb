# %% [markdown]
# # Summary:
#
# #### In this notebook, the trial runs from the preceding notebook ('01_So_What.ipynb') are systematically extended to try to find an optimal configuration for the two models. The model parameters to be fine tuned are: number of epochs, number of layers and the number of units.
#
# #### The best performing model configuration will be used in the notebook '03_Blue_in_Green.ipynb' to analyze the impact of adding noise to the clean dataset.

# %% [markdown]
# # Table of contents
# * [1. Load modules](#Part1_link)
# * [2. Setup data](#Part2_link)
# <br >&nbsp;&nbsp;&nbsp;[2.1  Generate data, separate testing and validation set and standardize testing data](#Part2.1_link)
# * [3. Setup models and evaluate for various hyper-parameter choices](#Part3_link)
# <br >&nbsp;&nbsp;&nbsp;[3.1 Compile and fit LSTM and RNN model](#Part3.1_link)
# * [4. Visualize results](#Part4_link)

# %% [markdown]
# <a id='Part1_link'></a>
# # 1. Load modules

# %%
import sys
sys.path.append("../src/")
import Kind_of_Blue  # own class with a collection of methods used in this analysis

import tensorflow as tf

import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

import numpy as np
import pandas as pd

# %% [markdown]
# <a id='Part2_link'></a>
# # 2. Setup data

# %% [markdown]
# <a id='Part2.1_link'></a>
# ### 2.1 Generate data, separate testing and validation set and standardize testing data

# %% [markdown]
# The following steps are repeated from the previous notebook, '01_So_What.ipynb', and are grouped into one single step here for simplicity.

# %%
# set a range of dates on which the observations are made
idx = pd.date_range(end='7/1/2020', periods=5*364, freq='d')

# take a sine function as the observations
num_periods = 10  # number of sine periods
observations = [np.sin(2*np.pi*num_periods*x/len(idx)) for x in range(len(idx))]
print('number of observations in time series: {}'.format(len(observations)))

# initialize dataframe to store time series
df = pd.DataFrame(data=observations, columns=['observations'])
df.index = idx

# initialize object
mdq = Kind_of_Blue.Kind_of_Blue()

# load dataframe into object
mdq._selected_features = ['observations']
mdq.df = df

# train-validation split ratio as class attribute set to 70%
print('train split ratio = ', mdq.TRAIN_SPLIT_RATIO)

# initialize dataset from dataframe 
mdq.initialize_dataset()
print('loaded data set length: {}'.format(len(mdq._dataset)))

# standardize data
mdq.standardize_data()

# check that mean equals zero and the standard deviation is one
print('mean: {}, std: {}'.format(round(np.mean(mdq._dataset), 2), round(np.std(mdq._dataset), 2)))

# set number of time points for 1/ future forecasting points and 2/ the past, historical time points
future_target_size = int(365/52)
past_history_size = int(1*365)

# set batch size
batch_size = 32

# generate train and validation data
mdq.generate_train_and_val_data(future_target_size=future_target_size, past_history_size=past_history_size
                                , batch_size=batch_size)

print('number of training samples: {}'.format(mdq._num_samples))
# Out:
# number of observations in time series: 1820
# train split ratio =  0.7
# loaded data set length: 1820
# mean: 0.0, std: 1.0
# training set shape: x:(909, 365, 1), y:(909, 7, 1)
# validation set shape: x:(174, 365, 1), y:(174, 7, 1)
# number of training samples: 909

# %% [markdown]
# <a id='Part3_link'></a>
# # 3. Setup models and evaluate for various hyper-parameter choices

# %% [markdown]
# <a id='Part3.1_link'></a>
# ### 3.1 Compile and fit LSTM and RNN model

# %%
# generator for configurations to be iterated over

def config_generator():
    
    unit_choices = [128, 512]  # number of units in each neural network layer
    layer_choices = [2]  # total number of layers
    epoch_choices = [30, 100]  # number of epochs the model is trained on
    
    for units in unit_choices:
        for num_layers in layer_choices:
            for epochs in epoch_choices:
                yield units, num_layers, epochs

# %%
# iterations over the model parameter configurations are done for both LSTM as well as RNN model
# model_types = ['LSTM', 'RNN']
model_types = ['RNN']

# set number of steps per epoch
num_samples = mdq._num_samples
steps_per_epoch = int(num_samples/future_target_size)
validation_steps = int(steps_per_epoch/2)

# initialize results dictionary
res = {'model_type': [], 'epochs': [], 'num_layers': [], 'units': [], 'val_mse': []
       , 'mse': [], 'total_training_time': []}

for units, num_layers, epochs in config_generator():
    for model_type in model_types:

        print('currently running {} model with units, num_layers, epochs as {}, {}, {}'.format(model_type
                                                                                       , units
                                                                                       , num_layers
                                                                                       , epochs))

        # compile model
        mdq.compile_model(units=units, num_layers=num_layers, model_type=model_type)

        # fit model
        mdq.fit_model(epochs=epochs, steps_per_epoch=steps_per_epoch
                      ,validation_steps=validation_steps, model_type=model_type)
        
        # get errors
        history = mdq._histories[model_type]
        val_mse = history.history['val_mse'][-1]
        mse = history.history['mse'][-1]
        
        # get total training time
        total_training_time = sum(mdq._time_callbacks[model_type].times)
        
        # append results to results dictionary
        res['model_type'].append(model_type)
        res['epochs'].append(epochs)
        res['num_layers'].append(num_layers)
        res['units'].append(units)
        res['val_mse'].append(val_mse)
        res['mse'].append(mse)
        res['total_training_time'].append(total_training_time)
# Out:
# currently running RNN model with units, num_layers, epochs as 128, 2, 30
# Epoch 1/30
# 129/129 [==============================] - 13s 100ms/step - loss: 0.1001 - mse: 0.1001 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 2/30
# 129/129 [==============================] - 14s 105ms/step - loss: 0.0238 - mse: 0.0238 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 3/30
# 129/129 [==============================] - 14s 108ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 4/30
# 129/129 [==============================] - 14s 105ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 5/30
# 129/129 [==============================] - 12s 97ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 5.7838e-04 - val_mse: 5.7838e-04
# Epoch 6/30
# 129/129 [==============================] - 12s 95ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 7/30
# 129/129 [==============================] - 12s 94ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 7.6476e-04 - val_mse: 7.6476e-04
# Epoch 8/30
# 129/129 [==============================] - 13s 98ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 9/30
# 129/129 [==============================] - 14s 106ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 9.1677e-04 - val_mse: 9.1677e-04
# Epoch 10/30
# 129/129 [==============================] - 14s 105ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 9.1814e-04 - val_mse: 9.1814e-04
# Epoch 11/30
# 129/129 [==============================] - 14s 108ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 12/30
# 129/129 [==============================] - 12s 94ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 5.3288e-04 - val_mse: 5.3288e-04
# Epoch 13/30
# 129/129 [==============================] - 12s 96ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 5.7353e-04 - val_mse: 5.7353e-04
# Epoch 14/30
# 129/129 [==============================] - 12s 94ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 5.4318e-04 - val_mse: 5.4318e-04
# Epoch 15/30
# 129/129 [==============================] - 12s 94ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 8.7151e-04 - val_mse: 8.7151e-04
# Epoch 16/30
# 129/129 [==============================] - 12s 95ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 17/30
# 129/129 [==============================] - 13s 100ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 1.0400e-04 - val_mse: 1.0400e-04
# Epoch 18/30
# 129/129 [==============================] - 12s 95ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 9.5899e-04 - val_mse: 9.5899e-04
# Epoch 19/30
# 129/129 [==============================] - 12s 94ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 20/30
# 129/129 [==============================] - 12s 94ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 21/30
# 129/129 [==============================] - 12s 97ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 7.0020e-04 - val_mse: 7.0020e-04
# Epoch 22/30
# 129/129 [==============================] - 15s 118ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 3.3944e-04 - val_mse: 3.3944e-04
# Epoch 23/30
# 129/129 [==============================] - 14s 108ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 24/30
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 25/30
# 129/129 [==============================] - 14s 111ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 3.4072e-04 - val_mse: 3.4072e-04
# Epoch 26/30
# 129/129 [==============================] - 14s 107ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 5.2912e-04 - val_mse: 5.2912e-04
# Epoch 27/30
# 129/129 [==============================] - 14s 107ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 5.4681e-04 - val_mse: 5.4681e-04
# Epoch 28/30
# 129/129 [==============================] - 14s 107ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 8.9865e-04 - val_mse: 8.9865e-04
# Epoch 29/30
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 6.0628e-04 - val_mse: 6.0628e-04
# Epoch 30/30
# 129/129 [==============================] - 13s 104ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 2.3118e-04 - val_mse: 2.3118e-04
# currently running RNN model with units, num_layers, epochs as 128, 2, 100
# Epoch 1/100
# 129/129 [==============================] - 14s 106ms/step - loss: 0.0638 - mse: 0.0638 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 2/100
# 129/129 [==============================] - 13s 104ms/step - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 3/100
# 129/129 [==============================] - 13s 104ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 8.4522e-04 - val_mse: 8.4522e-04
# Epoch 4/100
# 129/129 [==============================] - 13s 104ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 5/100
# 129/129 [==============================] - 13s 104ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 4.4438e-04 - val_mse: 4.4438e-04
# Epoch 6/100
# 129/129 [==============================] - 13s 104ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 7/100
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 8/100
# 129/129 [==============================] - 13s 104ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 9/100
# 129/129 [==============================] - 13s 104ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 10/100
# 129/129 [==============================] - 13s 105ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 11/100
# 129/129 [==============================] - 13s 104ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 3.9966e-04 - val_mse: 3.9966e-04
# Epoch 12/100
# 129/129 [==============================] - 13s 104ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 7.4802e-04 - val_mse: 7.4802e-04
# Epoch 13/100
# 129/129 [==============================] - 13s 104ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 14/100
# 129/129 [==============================] - 13s 104ms/step - loss: 1.0186 - mse: 1.0186 - val_loss: 0.2710 - val_mse: 0.2710
# Epoch 15/100
# 129/129 [==============================] - 13s 104ms/step - loss: 0.2227 - mse: 0.2227 - val_loss: 0.1747 - val_mse: 0.1747
# Epoch 16/100
# 129/129 [==============================] - 13s 104ms/step - loss: 0.1648 - mse: 0.1648 - val_loss: 0.1080 - val_mse: 0.1080
# Epoch 17/100
# 129/129 [==============================] - 14s 105ms/step - loss: 0.0855 - mse: 0.0855 - val_loss: 0.0483 - val_mse: 0.0483
# Epoch 18/100
# 129/129 [==============================] - 13s 104ms/step - loss: 0.0556 - mse: 0.0556 - val_loss: 0.0363 - val_mse: 0.0363
# Epoch 19/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0427 - mse: 0.0427 - val_loss: 0.0415 - val_mse: 0.0415
# Epoch 20/100
# 129/129 [==============================] - 13s 104ms/step - loss: 0.0388 - mse: 0.0388 - val_loss: 0.0278 - val_mse: 0.0278
# Epoch 21/100
# 129/129 [==============================] - 13s 105ms/step - loss: 0.0377 - mse: 0.0377 - val_loss: 0.0264 - val_mse: 0.0264
# Epoch 22/100
# 129/129 [==============================] - 14s 105ms/step - loss: 0.0376 - mse: 0.0376 - val_loss: 0.0266 - val_mse: 0.0266
# Epoch 23/100
# 129/129 [==============================] - 14s 112ms/step - loss: 0.0371 - mse: 0.0371 - val_loss: 0.0326 - val_mse: 0.0326
# Epoch 24/100
# 129/129 [==============================] - 15s 116ms/step - loss: 0.0354 - mse: 0.0354 - val_loss: 0.0290 - val_mse: 0.0290
# Epoch 25/100
# 129/129 [==============================] - 15s 116ms/step - loss: 0.0360 - mse: 0.0360 - val_loss: 0.0307 - val_mse: 0.0307
# Epoch 26/100
# 129/129 [==============================] - 14s 112ms/step - loss: 0.0357 - mse: 0.0357 - val_loss: 0.0291 - val_mse: 0.0291
# Epoch 27/100
# 129/129 [==============================] - 14s 106ms/step - loss: 0.0367 - mse: 0.0367 - val_loss: 0.0274 - val_mse: 0.0274
# Epoch 28/100
# 129/129 [==============================] - 14s 105ms/step - loss: 0.0369 - mse: 0.0369 - val_loss: 0.0246 - val_mse: 0.0246
# Epoch 29/100
# 129/129 [==============================] - 13s 101ms/step - loss: 0.0349 - mse: 0.0349 - val_loss: 0.0254 - val_mse: 0.0254
# Epoch 30/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0372 - mse: 0.0372 - val_loss: 0.0324 - val_mse: 0.0324
# Epoch 31/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0358 - mse: 0.0358 - val_loss: 0.0238 - val_mse: 0.0238
# Epoch 32/100
# 129/129 [==============================] - 13s 101ms/step - loss: 0.0342 - mse: 0.0342 - val_loss: 0.0283 - val_mse: 0.0283
# Epoch 33/100
# 129/129 [==============================] - 13s 101ms/step - loss: 0.0349 - mse: 0.0349 - val_loss: 0.0248 - val_mse: 0.0248
# Epoch 34/100
# 129/129 [==============================] - 13s 101ms/step - loss: 0.0330 - mse: 0.0330 - val_loss: 0.0296 - val_mse: 0.0296
# Epoch 35/100
# 129/129 [==============================] - 13s 101ms/step - loss: 0.0314 - mse: 0.0314 - val_loss: 0.0404 - val_mse: 0.0404
# Epoch 36/100
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0313 - mse: 0.0313 - val_loss: 0.0232 - val_mse: 0.0232
# Epoch 37/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0300 - mse: 0.0300 - val_loss: 0.0257 - val_mse: 0.0257
# Epoch 38/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0291 - mse: 0.0291 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 39/100
# 129/129 [==============================] - 14s 105ms/step - loss: 0.0299 - mse: 0.0299 - val_loss: 0.0217 - val_mse: 0.0217
# Epoch 40/100
# 129/129 [==============================] - 14s 105ms/step - loss: 0.0274 - mse: 0.0274 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 41/100
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0221 - mse: 0.0221 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 42/100
# 129/129 [==============================] - 13s 101ms/step - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 43/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 44/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 45/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 46/100
# 129/129 [==============================] - 13s 101ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 47/100
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 48/100
# 129/129 [==============================] - 13s 101ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 7.7579e-04 - val_mse: 7.7579e-04
# Epoch 49/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 50/100
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 51/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 52/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 53/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 54/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 55/100
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 56/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 7.3558e-04 - val_mse: 7.3558e-04
# Epoch 57/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 58/100
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 59/100
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 60/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 61/100
# 129/129 [==============================] - 14s 109ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 62/100
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 63/100
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 64/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 65/100
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 66/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 67/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 6.6887e-04 - val_mse: 6.6887e-04
# Epoch 68/100
# 129/129 [==============================] - 15s 120ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 69/100
# 129/129 [==============================] - 15s 115ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 3.4248e-04 - val_mse: 3.4248e-04
# Epoch 70/100
# 129/129 [==============================] - 15s 115ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 4.4160e-04 - val_mse: 4.4160e-04
# Epoch 71/100
# 129/129 [==============================] - 14s 105ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 72/100
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 6.2487e-04 - val_mse: 6.2487e-04
# Epoch 73/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 74/100
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 4.8994e-04 - val_mse: 4.8994e-04
# Epoch 75/100
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 76/100
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 3.4454e-04 - val_mse: 3.4454e-04
# Epoch 77/100
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 78/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 79/100
# 129/129 [==============================] - 13s 102ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 5.7472e-04 - val_mse: 5.7472e-04
# Epoch 80/100
# 129/129 [==============================] - 13s 103ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 81/100
# 129/129 [==============================] - 14s 108ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 82/100
# 129/129 [==============================] - 16s 126ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 83/100
# 129/129 [==============================] - 16s 125ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 84/100
# 129/129 [==============================] - 16s 124ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 85/100
# 129/129 [==============================] - 15s 120ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 86/100
# 129/129 [==============================] - 15s 119ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 87/100
# 129/129 [==============================] - 16s 121ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 88/100
# 129/129 [==============================] - 16s 121ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 89/100
# 129/129 [==============================] - 15s 119ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 90/100
# 129/129 [==============================] - 15s 120ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 91/100
# 129/129 [==============================] - 16s 122ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 92/100
# 129/129 [==============================] - 16s 123ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch
ms/step - loss: 0.0598 - mse: 0.0598 - val_loss: 0.0335 - val_mse: 0.0335
# Epoch 88/100
# 129/129 [==============================] - 66s 508ms/step - loss: 0.0577 - mse: 0.0577 - val_loss: 0.0317 - val_mse: 0.0317
# Epoch 89/100
# 129/129 [==============================] - 54s 421ms/step - loss: 0.0553 - mse: 0.0553 - val_loss: 0.0408 - val_mse: 0.0408
# Epoch 90/100
# 129/129 [==============================] - 54s 418ms/step - loss: 0.0549 - mse: 0.0549 - val_loss: 0.0332 - val_mse: 0.0332
# Epoch 91/100
# 129/129 [==============================] - 54s 418ms/step - loss: 0.0565 - mse: 0.0565 - val_loss: 0.0324 - val_mse: 0.0324
# Epoch 92/100
# 129/129 [==============================] - 54s 418ms/step - loss: 0.0609 - mse: 0.0609 - val_loss: 0.0320 - val_mse: 0.0320
# Epoch 93/100
# 129/129 [==============================] - 54s 418ms/step - loss: 0.0552 - mse: 0.0552 - val_loss: 0.0307 - val_mse: 0.0307
# Epoch 94/100
# 129/129 [==============================] - 60s 469ms/step - loss: 0.0581 - mse: 0.0581 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 95/100
# 129/129 [==============================] - 54s 421ms/step - loss: 0.0541 - mse: 0.0541 - val_loss: 0.0349 - val_mse: 0.0349
# Epoch 96/100
# 129/129 [==============================] - 54s 417ms/step - loss: 0.0546 - mse: 0.0546 - val_loss: 0.0316 - val_mse: 0.0316
# Epoch 97/100
# 129/129 [==============================] - 54s 418ms/step - loss: 0.0574 - mse: 0.0574 - val_loss: 0.0346 - val_mse: 0.0346
# Epoch 98/100
# 129/129 [==============================] - 54s 418ms/step - loss: 0.0536 - mse: 0.0536 - val_loss: 0.0394 - val_mse: 0.0394
# Epoch 99/100
# 129/129 [==============================] - 54s 419ms/step - loss: 0.0550 - mse: 0.0550 - val_loss: 0.0333 - val_mse: 0.0333
# Epoch 100/100
# 129/129 [==============================] - 54s 421ms/step - loss: 0.0581 - mse: 0.0581 - val_loss: 0.0412 - val_mse: 0.0412

# %% [markdown]
# <a id='Part4_link'></a>
# # 4. Visualize results

# %%
# transform dictionary to dataframe
df_res = pd.DataFrame(res)

# store dataframe as csv locally
df_res.to_csv('../data/02_results_run6.csv')

# %%
# visualize results; use bubble plots to indicate magnitude of mean-square error for specific configuration comparing
# RNN to LSTM results

x_label = 'epochs'
y_label = 'units'
z_label = 'mse'
# condition_label = 'num_layers'
# condition_vals = list(set(df_res[condition_label]))

# condition_LSTM = (df_res['model_type']=='LSTM')
# condition_RNN = (df_res['model_type']=='RNN')

for model_type in ['LSTM', 'RNN']:
    condition_1 = (df_res['model_type']== model_type)
    
    x = df_res[condition_1][x_label].values
    y = df_res[condition_1][y_label].values
    
    z = df_res[condition_1][z_label].values
    plt.scatter(x, y, s=z*10000, alpha=0.6, c="red", linewidth=0.0)
        
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title('mean-square training error: {} model'.format(model_type))
    plt.show()

# %%
df_res[df_res['model_type']=='RNN']
# Out:
#   model_type  epochs  num_layers  units   val_mse       mse  \
# 0        RNN      30           2    128  0.000231  0.006107
# 1        RNN     100           2    128  0.022678  0.033231
# 2        RNN      30           2    512  0.096322  0.093770
# 3        RNN     100           2    512  0.041203  0.058073
#
#    total_training_time
# 0           395.819445
# 1          1405.958149
# 2          7551.894192
# 3          6025.916133
